# %%
# Setup and imports
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import arviz as az

import pandas as pd
import sys

from bayes import process_measurements, build_hierarchical_bayesian_model, calculate_range, compile_results, reference_intervals_sex, plot_ranges
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 10
#       7 import pandas as pd
#       8 import sys
# ---> 10 from bayes import process_measurements, build_hierarchical_bayesian_model, calculate_range, compile_results, reference_intervals_sex, plot_ranges
#
# File ~/Desktop/ssh_mount/SETPOINT/bayes/bayes.py:12
#       9 from sklearn.mixture import GaussianMixture
#      11 sys.path.append('../setpoint/')
# ---> 12 from setpoint.setpoint import process_dataframe, process_data, filter_measurements, calculate_setpoint, calculate_cv, main
#      14 sys.path.append('../data_process/')
#      15 from processors.cbc import CBC_REFERENCE_INTERVALS
#
# ModuleNotFoundError: No module named 'setpoint.setpoint'; 'setpoint' is not a package
